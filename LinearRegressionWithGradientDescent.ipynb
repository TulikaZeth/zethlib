# %% [markdown]
# <a href="https://colab.research.google.com/github/TulikaZeth/zethlib/blob/main/minitullslib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# here i am planning to make a mini python library of my own to practice my ML algos and knowledge

# %%
# Linear Regression (Normal Eq + Gradient Descent)  STARTING WITH THIS ALGO!!

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt

class LinearRegressionGD:
    def __init__(self, lr=0.01, epochs=1000):
        self.lr = lr
        self.epochs = epochs
        self.w = None
        self.b = None
        self.losses = []

    def fit(self, X, y):
        X = np.array(X, dtype=float)
        y = np.array(y, dtype=float)

        n_samples, n_features = X.shape
        self.w = np.zeros(n_features)
        self.b = 0

        for i in range(self.epochs):

            y_pred = np.dot(X, self.w) + self.b


            dw = (1/n_samples) * np.dot(X.T, (y_pred - y))
            db = (1/n_samples) * np.sum(y_pred - y)

            self.w -= self.lr * dw
            self.b -= self.lr * db


            loss = np.mean((y_pred - y)**2)
            self.losses.append(loss)

            if i % 100 == 0:
                print(f"Epoch {i}, Loss: {loss:.4f}")

    def predict(self, X):
        X = np.array(X, dtype=float)
        return np.dot(X, self.w) + self.b



X = np.array([[1], [2], [3], [4], [5]], dtype=float)
y = np.array([5, 7, 9, 11, 13], dtype=float)  # y = 2x + 3

model = LinearRegressionGD(lr=0.01, epochs=1000)
model.fit(X, y)

print("\nWeights:", model.w)
print("Bias:", model.b)

print("Prediction for x=6:", model.predict([[6]]))

plt.plot(model.losses)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss Curve")
plt.show()
# Out:
# Epoch 0, Loss: 89.0000
# Epoch 100, Loss: 0.6697
# Epoch 200, Loss: 0.4774
# Epoch 300, Loss: 0.3404
# Epoch 400, Loss: 0.2427
# Epoch 500, Loss: 0.1730
# Epoch 600, Loss: 0.1233
# Epoch 700, Loss: 0.0879
# Epoch 800, Loss: 0.0627
# Epoch 900, Loss: 0.0447
#
# Weights: [2.1158847]
# Bias: 2.581619456736265
# Prediction for x=6: [15.27692767]

# %%
# lr :learning rate define krta h
# more the lr faster the learning ,

# epochs : the number of times the model looks at the data while training
# weights : line's slope . Initially None , but then initizialied with 0
# bias : line's intercept . Initially None , but then initizialied with 0
# losses: array to store the losses during training the model


# Input X and y ko numpy arrays me convert krdia kyoki numpy faster matrix operatrions deta
# dtype = float , kyuki maths float number pr easily and smoothly kaam krta h

# X.shape : shape nikalne ke lie and har feature ke lie ek weight hota h usko set krne ke lie np.zeros use krte h
# b = 0 . se bias ko bhi 0 se set krdia

# y_pred = np.dot(X, self.w) + self.b
# use kia h kyoki yeh LR ka formula h and np.dot matrix multiplication ke kaam ata h , b is added to output kyoki woh bias h

# dw(gradient of weight) : yaha model sikhne ka kam krta h
# Error = [predicted - actual]
# is error ko input (X) se multiply krke weight ka gradient nikalte
# X.T = transpose (column -> row)

# bias ka gradient bas error ka average hota h

# gradient basically yeh batata h ki is direction me update kro takki loss kam hooks

# GRADIENT DESCENT KA FORMULA : w = w - learning rate * dw

# GRADIENT DESCENT KA FORMULA : b = b - learning rate * db

# agr dw positive h toh weight ko kam kro and agr negative h toh weight ko badhao

# agr dw negative h toh bias ko kam kro and agr positive h toh bias ko badhao

# aise step by step ham best line tk pahuch pate h

# LOSS CALCULATION

# loss = np.mean(( y_pred - y) ** 2)
# self.losses.append(loss)

# yeh batata h ki model kitna loss me h and yeh har epoch ke bad me loss ko array me store krta h !!

# ham usi array ki help se phir apna loss wala graph plot krte h


# plt.plot(model.losses)
# loss curve dikhata h
# starting me loss zyada h and then gradually har epoch ke sath me loss kam hota jata h , end me training converge hojati h
# Out:
#   File "/tmp/ipython-input-3020973280.py", line 20
#     dw(gradient of weight) : yaha model sikhne ka kam krta h
#        ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
:
